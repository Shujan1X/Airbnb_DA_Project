# %%
import pandas as pd

# %%
df =pd.read_csv("ViratData.csv")

# %%
df
# Out:
#     Runs Mins  BF  4s 6s      SR Pos Dismissal Inns           Opposition  \
# 0     12   33  22   1  0   54.54   2       lbw    1      ODI v Sri Lanka
# 1     37   82  67   6  0   55.22   2    caught    2      ODI v Sri Lanka
# 2     25   40  38   4  0   65.78   1   run out    1      ODI v Sri Lanka
# 3     54   87  66   7  0   81.81   1    bowled    1      ODI v Sri Lanka
# 4     31   45  46   3  1   67.39   1       lbw    2      ODI v Sri Lanka
# ..   ...  ...  ..  .. ..     ...  ..       ...  ...                  ...
# 603   76  137  82  12  1   92.68   4    caught    3  Test v South Africa
# 604   46  103  59   6  1   77.96   4    caught    2  Test v South Africa
# 605   12   13  11   2  0  109.09   4    caught    4  Test v South Africa
# 606   29   20  16   5  0  181.25   3    caught    2   T20I v Afghanistan
# 607    0    1   1   0  0       0   3    caught    1   T20I v Afghanistan
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# ...

# %%
df['Match_Format'] = df['Opposition'].str.split('v').str[0].str.strip()

# %%
df
# Out:
#     Runs Mins  BF  4s 6s      SR Pos Dismissal Inns           Opposition  \
# 0     12   33  22   1  0   54.54   2       lbw    1      ODI v Sri Lanka
# 1     37   82  67   6  0   55.22   2    caught    2      ODI v Sri Lanka
# 2     25   40  38   4  0   65.78   1   run out    1      ODI v Sri Lanka
# 3     54   87  66   7  0   81.81   1    bowled    1      ODI v Sri Lanka
# 4     31   45  46   3  1   67.39   1       lbw    2      ODI v Sri Lanka
# ..   ...  ...  ..  .. ..     ...  ..       ...  ...                  ...
# 603   76  137  82  12  1   92.68   4    caught    3  Test v South Africa
# 604   46  103  59   6  1   77.96   4    caught    2  Test v South Africa
# 605   12   13  11   2  0  109.09   4    caught    4  Test v South Africa
# 606   29   20  16   5  0  181.25   3    caught    2   T20I v Afghanistan
# 607    0    1   1   0  0       0   3    caught    1   T20I v Afghanistan
#
#             Ground Start Date Match_Format
# 0         Dambulla  18-Aug-08          ODI
# ...

# %%
df['Match_Opposition'] = df['Opposition'].str.split('v').str[1].str.strip()

# %%
df.head()
# Out:
#   Runs Mins  BF 4s 6s     SR Pos Dismissal Inns       Opposition  \
# 0   12   33  22  1  0  54.54   2       lbw    1  ODI v Sri Lanka
# 1   37   82  67  6  0  55.22   2    caught    2  ODI v Sri Lanka
# 2   25   40  38  4  0  65.78   1   run out    1  ODI v Sri Lanka
# 3   54   87  66  7  0  81.81   1    bowled    1  ODI v Sri Lanka
# 4   31   45  46  3  1  67.39   1       lbw    2  ODI v Sri Lanka
#
#           Ground Start Date Match_Format Match_Opposition
# 0       Dambulla  18-Aug-08          ODI        Sri Lanka
# 1       Dambulla  20-Aug-08          ODI        Sri Lanka
# 2  Colombo (RPS)  24-Aug-08          ODI        Sri Lanka
# 3  Colombo (RPS)  27-Aug-08          ODI        Sri Lanka
# 4  Colombo (RPS)  29-Aug-08          ODI        Sri Lanka

# %%
df.drop(columns=['Opposition'], inplace=True)

# %%
df.head()
# Out:
#   Runs Mins  BF 4s 6s     SR Pos Dismissal Inns         Ground Start Date  \
# 0   12   33  22  1  0  54.54   2       lbw    1       Dambulla  18-Aug-08
# 1   37   82  67  6  0  55.22   2    caught    2       Dambulla  20-Aug-08
# 2   25   40  38  4  0  65.78   1   run out    1  Colombo (RPS)  24-Aug-08
# 3   54   87  66  7  0  81.81   1    bowled    1  Colombo (RPS)  27-Aug-08
# 4   31   45  46  3  1  67.39   1       lbw    2  Colombo (RPS)  29-Aug-08
#
#   Match_Format Match_Opposition
# 0          ODI        Sri Lanka
# 1          ODI        Sri Lanka
# 2          ODI        Sri Lanka
# 3          ODI        Sri Lanka
# 4          ODI        Sri Lanka

# %%
df.rename(columns={'Match_Opposition': 'Opposition'}, inplace=True)

# %%
df.head()
# Out:
#   Runs Mins  BF 4s 6s     SR Pos Dismissal Inns         Ground Start Date  \
# 0   12   33  22  1  0  54.54   2       lbw    1       Dambulla  18-Aug-08
# 1   37   82  67  6  0  55.22   2    caught    2       Dambulla  20-Aug-08
# 2   25   40  38  4  0  65.78   1   run out    1  Colombo (RPS)  24-Aug-08
# 3   54   87  66  7  0  81.81   1    bowled    1  Colombo (RPS)  27-Aug-08
# 4   31   45  46  3  1  67.39   1       lbw    2  Colombo (RPS)  29-Aug-08
#
#   Match_Format Opposition
# 0          ODI  Sri Lanka
# 1          ODI  Sri Lanka
# 2          ODI  Sri Lanka
# 3          ODI  Sri Lanka
# 4          ODI  Sri Lanka

# %%
df.dtypes
# Out:
# Runs            object
# Mins            object
# BF              object
# 4s              object
# 6s              object
# SR              object
# Pos             object
# Dismissal       object
# Inns            object
# Ground          object
# Start Date      object
# Match_Format    object
# Opposition      object
# dtype: object

# %%
df.rename(columns={'Pos': 'Batting Position',
'BF': 'Ball Faced',
'SR':'Strike Rate'},inplace=True)


# pos= Batting Position
# BF= Ball Faced
# SR=Strike Rate

# %%
df
# Out:
#     Runs Mins Ball Faced  4s 6s Strike Rate Batting Position Dismissal Inns  \
# 0     12   33         22   1  0       54.54                2       lbw    1
# 1     37   82         67   6  0       55.22                2    caught    2
# 2     25   40         38   4  0       65.78                1   run out    1
# 3     54   87         66   7  0       81.81                1    bowled    1
# 4     31   45         46   3  1       67.39                1       lbw    2
# ..   ...  ...        ...  .. ..         ...              ...       ...  ...
# 603   76  137         82  12  1       92.68                4    caught    3
# 604   46  103         59   6  1       77.96                4    caught    2
# 605   12   13         11   2  0      109.09                4    caught    4
# 606   29   20         16   5  0      181.25                3    caught    2
# 607    0    1          1   0  0           0                3    caught    1
#
#             Ground Start Date Match_Format    Opposition
# ...

# %%
tdnb_rows = df[df['Runs']=='TDNB']

# %%
tdnb_rows
# Out:
#      Runs Mins Ball Faced 4s 6s Strike Rate Batting Position Dismissal Inns  \
# 7    TDNB    -          -  -  -           -                -         -    -
# 14   TDNB    -          -  -  -           -                -         -    -
# 180  TDNB    -          -  -  -           -                -         -    -
# 293  TDNB    -          -  -  -           -                -         -    -
# 408  TDNB    -          -  -  -           -                -         -    -
# 442  TDNB    -          -  -  -           -                -         -    -
# 463  TDNB    -          -  -  -           -                -         -    -
#
#             Ground Start Date Match_Format    Opposition
# 7        Centurion  28-Sep-09          ODI     Australia
# 14           Delhi  27-Dec-09          ODI     Sri Lanka
# 180      Centurion  11-Dec-13          ODI  South Africa
# 293  Port of Spain  18-Aug-16         Test   West Indies
# 408      Melbourne  23-Nov-18         T20I     Australia
# ...

# %%
df.loc[tdnb_rows.index, ['Mins', 'Ball Faced', '4s', '6s', 'Strike Rate', 'Batting Position', 'Dismissal', 'Inns']] = 0

# %%
df[df['Runs'] == 'TDNB']
# Out:
#      Runs Mins Ball Faced 4s 6s Strike Rate Batting Position Dismissal Inns  \
# 7    TDNB    0          0  0  0           0                0         0    0
# 14   TDNB    0          0  0  0           0                0         0    0
# 180  TDNB    0          0  0  0           0                0         0    0
# 293  TDNB    0          0  0  0           0                0         0    0
# 408  TDNB    0          0  0  0           0                0         0    0
# 442  TDNB    0          0  0  0           0                0         0    0
# 463  TDNB    0          0  0  0           0                0         0    0
#
#             Ground Start Date Match_Format    Opposition   BF   SR  Pos
# 7        Centurion  28-Sep-09          ODI     Australia  0.0  0.0  0.0
# 14           Delhi  27-Dec-09          ODI     Sri Lanka  0.0  0.0  0.0
# 180      Centurion  11-Dec-13          ODI  South Africa  0.0  0.0  0.0
# 293  Port of Spain  18-Aug-16         Test   West Indies  0.0  0.0  0.0
# ...

# %%
df.loc[tdnb_rows.index, [ 'Dismissal']] = 'Team Did Not Bat'

# %%
df.drop(columns=['BF','SR','Pos'], inplace=True)

# %%
df.loc[tdnb_rows.index, ['Runs']] = 0

# %%
df[df['Runs'] == 0]
# Out:
#     Runs Mins Ball Faced 4s 6s Strike Rate Batting Position         Dismissal  \
# 7      0    0          0  0  0           0                0  Team Did Not Bat
# 14     0    0          0  0  0           0                0  Team Did Not Bat
# 180    0    0          0  0  0           0                0  Team Did Not Bat
# 293    0    0          0  0  0           0                0  Team Did Not Bat
# 408    0    0          0  0  0           0                0  Team Did Not Bat
# 442    0    0          0  0  0           0                0  Team Did Not Bat
# 463    0    0          0  0  0           0                0  Team Did Not Bat
#
#     Inns         Ground Start Date Match_Format    Opposition
# 7      0      Centurion  28-Sep-09          ODI     Australia
# 14     0          Delhi  27-Dec-09          ODI     Sri Lanka
# 180    0      Centurion  11-Dec-13          ODI  South Africa
# 293    0  Port of Spain  18-Aug-16         Test   West Indies
# ...

# %%
dnb_rows = df[df['Runs']=='DNB']

# %%
dnb_rows
# Out:
# Empty DataFrame
# Columns: [Runs, Mins, Ball Faced, 4s, 6s, Strike Rate, Batting Position, Dismissal, Inns, Ground, Start Date, Match_Format, Opposition]
# Index: []

# %%
df.loc[dnb_rows.index, ['Mins', 'Ball Faced', '4s', '6s', 'Strike Rate', 'Batting Position', 'Runs', 'Inns']] = 0

# %%
dnb_rows
# Out:
# Empty DataFrame
# Columns: [Runs, Mins, Ball Faced, 4s, 6s, Strike Rate, Batting Position, Dismissal, Inns, Ground, Start Date, Match_Format, Opposition]
# Index: []

# %%
df.head(10)
# Out:
#   Runs Mins Ball Faced 4s 6s Strike Rate Batting Position         Dismissal  \
# 0   12   33         22  1  0       54.54                2               lbw
# 1   37   82         67  6  0       55.22                2            caught
# 2   25   40         38  4  0       65.78                1           run out
# 3   54   87         66  7  0       81.81                1            bowled
# 4   31   45         46  3  1       67.39                1               lbw
# 5   2*    6          2  0  0         100                7           not out
# 6   16   28         24  1  0       66.66                4            caught
# 7    0    0          0  0  0           0                0  Team Did Not Bat
# 8  79*  121        104  9  2       75.96                4           not out
# 9   30   53         41  3  0       73.17                4            caught
#
#   Inns         Ground Start Date Match_Format   Opposition
# 0    1       Dambulla  18-Aug-08          ODI    Sri Lanka
# ...

# %%
df[df['Dismissal']=='-']
# Out:
#     Runs Mins Ball Faced 4s 6s Strike Rate Batting Position Dismissal Inns  \
# 21     0    0          0  0  0           0                0         -    0
# 28     0    0          0  0  0           0                0         -    0
# 68     0    0          0  0  0           0                0         -    0
# 109    0    0          0  0  0           0                0         -    0
# 145    0    0          0  0  0           0                0         -    0
# 164    0    0          0  0  0           0                0         -    0
# 165    0    0          0  0  0           0                0         -    0
# 170    0    0          0  0  0           0                0         -    0
# 197    0    0          0  0  0           0                0         -    0
# 266    0    0          0  0  0           0                0         -    0
# 282    0    0          0  0  0           0                0         -    0
# ...

# %%
dnb_rows=df[df['Dismissal']=='-']

# %%
dnb_rows
# Out:
#     Runs Mins Ball Faced 4s 6s Strike Rate Batting Position Dismissal Inns  \
# 21     0    0          0  0  0           0                0         -    0
# 28     0    0          0  0  0           0                0         -    0
# 68     0    0          0  0  0           0                0         -    0
# 109    0    0          0  0  0           0                0         -    0
# 145    0    0          0  0  0           0                0         -    0
# 164    0    0          0  0  0           0                0         -    0
# 165    0    0          0  0  0           0                0         -    0
# 170    0    0          0  0  0           0                0         -    0
# 197    0    0          0  0  0           0                0         -    0
# 266    0    0          0  0  0           0                0         -    0
# 282    0    0          0  0  0           0                0         -    0
# ...

# %%
df.loc[dnb_rows.index, ['Dismissal']] ='Did Not Bat'

# %%
df.head(25)
# Out:
#     Runs Mins Ball Faced  4s 6s Strike Rate Batting Position  \
# 0     12   33         22   1  0       54.54                2
# 1     37   82         67   6  0       55.22                2
# 2     25   40         38   4  0       65.78                1
# 3     54   87         66   7  0       81.81                1
# 4     31   45         46   3  1       67.39                1
# 5     2*    6          2   0  0         100                7
# 6     16   28         24   1  0       66.66                4
# 7      0    0          0   0  0           0                0
# 8    79*  121        104   9  2       75.96                4
# 9     30   53         41   3  0       73.17                4
# 10    10   32         16   1  0        62.5                3
# 11    27   20         19   4  0       142.1                7
# 12    54   93         65   7  0       83.07                4
# 13   107    -        114  11  1       93.85                4
# ...

# %%
df[df['Dismissal']=='not out']
# Out:
#      Runs Mins Ball Faced  4s 6s Strike Rate Batting Position Dismissal Inns  \
# 5      2*    6          2   0  0         100                7   not out    1
# 8     79*  121        104   9  2       75.96                4   not out    2
# 17    71*   98         68   9  0      104.41                3   not out    2
# 18   102*  128         95  11  0      107.36                3   not out    2
# 27    26*   30         21   3  1       123.8                5   not out    2
# ..    ...  ...        ...  .. ..         ...              ...       ...  ...
# 566  166*  173        110  13  8       150.9                3   not out    1
# 587  122*  147         94   9  3      129.78                3   not out    1
# 592   55*   64         56   6  0       98.21                3   not out    2
# 594  103*  113         97   6  4      106.18                3   not out    2
# 598  101*  195        121  10  0       83.47                3   not out    1
#
# ...

# %%
df['Runs'] = df['Runs'].str.replace('*', '')

# %%
df[df['Dismissal']=='not out']
# Out:
#     Runs Mins Ball Faced  4s 6s Strike Rate Batting Position Dismissal Inns  \
# 5      2    6          2   0  0         100                7   not out    1
# 8     79  121        104   9  2       75.96                4   not out    2
# 17    71   98         68   9  0      104.41                3   not out    2
# 18   102  128         95  11  0      107.36                3   not out    2
# 27    26   30         21   3  1       123.8                5   not out    2
# ..   ...  ...        ...  .. ..         ...              ...       ...  ...
# 566  166  173        110  13  8       150.9                3   not out    1
# 587  122  147         94   9  3      129.78                3   not out    1
# 592   55   64         56   6  0       98.21                3   not out    2
# 594  103  113         97   6  4      106.18                3   not out    2
# 598  101  195        121  10  0       83.47                3   not out    1
#
# ...

# %%
df.to_csv('modified_virat_data.csv', index=False)

# %%
runsin_dnb=df[df['Dismissal']=='Did Not Bat']

# %%
runsin_dnb
# Out:
#     Runs Mins Ball Faced 4s 6s Strike Rate Batting Position    Dismissal Inns  \
# 21   NaN    0          0  0  0           0                0  Did Not Bat    0
# 28   NaN    0          0  0  0           0                0  Did Not Bat    0
# 68   NaN    0          0  0  0           0                0  Did Not Bat    0
# 109  NaN    0          0  0  0           0                0  Did Not Bat    0
# 145  NaN    0          0  0  0           0                0  Did Not Bat    0
# 164  NaN    0          0  0  0           0                0  Did Not Bat    0
# 165  NaN    0          0  0  0           0                0  Did Not Bat    0
# 170  NaN    0          0  0  0           0                0  Did Not Bat    0
# 197  NaN    0          0  0  0           0                0  Did Not Bat    0
# 266  NaN    0          0  0  0           0                0  Did Not Bat    0
# 282  NaN    0          0  0  0           0                0  Did Not Bat    0
# ...

# %%
df.loc[runsin_dnb.index, ['Runs']] = 0

# %%
runsin_dnb
# Out:
#     Runs Mins Ball Faced 4s 6s Strike Rate Batting Position    Dismissal Inns  \
# 21   NaN    0          0  0  0           0                0  Did Not Bat    0
# 28   NaN    0          0  0  0           0                0  Did Not Bat    0
# 68   NaN    0          0  0  0           0                0  Did Not Bat    0
# 109  NaN    0          0  0  0           0                0  Did Not Bat    0
# 145  NaN    0          0  0  0           0                0  Did Not Bat    0
# 164  NaN    0          0  0  0           0                0  Did Not Bat    0
# 165  NaN    0          0  0  0           0                0  Did Not Bat    0
# 170  NaN    0          0  0  0           0                0  Did Not Bat    0
# 197  NaN    0          0  0  0           0                0  Did Not Bat    0
# 266  NaN    0          0  0  0           0                0  Did Not Bat    0
# 282  NaN    0          0  0  0           0                0  Did Not Bat    0
# ...

# %%
df.head(25)
# Out:
#    Runs Mins Ball Faced  4s 6s Strike Rate Batting Position         Dismissal  \
# 0    12   33         22   1  0       54.54                2               lbw
# 1    37   82         67   6  0       55.22                2            caught
# 2    25   40         38   4  0       65.78                1           run out
# 3    54   87         66   7  0       81.81                1            bowled
# 4    31   45         46   3  1       67.39                1               lbw
# 5     2    6          2   0  0         100                7           not out
# 6    16   28         24   1  0       66.66                4            caught
# 7   NaN    0          0   0  0           0                0  Team Did Not Bat
# 8    79  121        104   9  2       75.96                4           not out
# 9    30   53         41   3  0       73.17                4            caught
# 10   10   32         16   1  0        62.5                3            caught
# ...

# %%
df=pd.read_csv("modified_virat_data.csv")

# %%
df
# Out:
#          Match ID  Runs Mins  Ball Faced  4s  6s Strike Rate  \
# 0     ODI # 2742   12.0   33          22   1   0       54.54
# 1     ODI # 2745   37.0   82          67   6   0       55.22
# 2     ODI # 2750   25.0   40          38   4   0       65.78
# 3      ODI # 2755  54.0   87          66   7   0       81.81
# 4      ODI # 2756  31.0   45          46   3   1       67.39
# ..            ...   ...  ...         ...  ..  ..         ...
# 603    Test #2520  76.0  137          82  12   1       92.68
# 604   Test #2522   46.0  103          59   6   1       77.96
# 605   Test #2522   12.0   13          11   2   0      109.09
# 606  T20I # 2431   29.0   20          16   5   0      181.25
# 607   T20I # 2435   0.0    1           1   0   0           0
#
#      Batting Position Dismissal  Inns         Ground Start Date Match_Format  \
# 0                   2       lbw     1       Dambulla  18-Aug-08          ODI
# ...

# %%
df1=pd.read_csv("Book1.csv")

# %%
df1
# Out:
#             Won
# 0    ODI # 2904
# 1    ODI # 2941
# 2    ODI # 2983
# 3    ODI # 2993
# 4    ODI # 2996
# 5    ODI # 3039
# 6    ODI # 3233
# 7    ODI # 3251
# 8    ODI # 3259
# 9    ODI # 3263
# 10   T20I # 265
# 11   T20I # 272
# 12   T20I # 282
# 13   T20I # 286
# 14   ODI # 3363
# 15   ODI # 3368
# 16   ODI # 3372
# 17   ODI # 3376
# 18   ODI # 3387
# 19   ODI # 3388
# 20   ODI # 3483
# 21   T20I # 378
# 22   T20I # 382
# 23   T20I # 393
# 24   T20I # 399
# 25   ODI # 3602
# 26   ODI # 3610
# 27   ODI # 3618
# 28   ODI # 3625
# 29   ODI # 3631
# 30   ODI # 3636
# 31   ODI # 3641
# 32   T20I # 512
# 33   T20I # 515
# 34   T20I # 517
# 35   ODI # 3878
# 36   ODI # 3886
# 37   ODI # 3891
# 38   ODI # 4150
# 39   ODI # 4155
# 40   ODI # 4161
# 41   ODI # 4169
# 42   ODI # 4175
# 43   ODI # 4182
# 44   ODI # 4187
# 45   T20I # 842
# 46   T20I # 843
# 47  T20I # 1390
# 48  T20I # 1396
# 49  T20I # 1410
# 50  T20I # 1750
# 51  T20I # 1754
# 52  T20I # 1761
# 53  T20I # 1842
# ...

# %%
merged_data = pd.merge(df, df1, left_on='Match ID', right_on='Won')

# %%
merged_data
# Out:
#      Match ID  Runs Mins  Ball Faced  4s  6s Strike Rate  Batting Position  \
# 0  ODI # 2941  71.0   98          68   9   0      104.41                 3
# 1  ODI # 3363  31.0   46          41   2   0        75.6                 3
# 2  T20I # 399  72.0   67          44   5   2      163.63                 3
#
#   Dismissal  Inns   Ground Start Date Match_Format    Opposition         Won
# 0   not out     2   Mirpur  10-Jan-10          ODI     Sri Lanka  ODI # 2941
# 1    caught     1  Cardiff  06-Jun-13          ODI  South Africa  ODI # 3363
# 2   not out     2   Mirpur  04-Apr-14         T20I  South Africa  T20I # 399
